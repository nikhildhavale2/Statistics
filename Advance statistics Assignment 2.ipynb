# %% [markdown]
# **Q1 Define the z-statistic and explain its relationship to the standard normal distribution. How is the z-statistic used in hypothesis testing?**

# %% [markdown]
# **Z-Statistic**
# The z-statistic, also known as the z-score, measures the number of standard deviations a data point is from the mean of a dataset. It's a way of standardizing scores on a common scale without units, allowing for comparisons across different distributions.
#
# **Formula for Z-Statistic**
# The formula to calculate the z-score (z) is: 𝑧 = 𝑋−𝜇/𝜎
#
# Where:
#
# 𝑋 = value of the data point
#
# 𝜇 = mean of the population
#
# 𝜎 = standard deviation of the population
#
# Relationship to the Standard Normal Distribution
# The z-score transforms any normal distribution to the standard normal distribution, which has a mean of 0 and a standard deviation of 1. The standard normal distribution is a special case of the normal distribution and is represented by the following properties:
#
# Mean (µ) = 0
#
# Standard Deviation (σ) = 1
#
# A z-score tells you where a data point lies in relation to the mean of the dataset. For example:
#
# A z-score of 0 means the data point is exactly at the mean.
#
# A z-score of +1 means the data point is one standard deviation above the mean.
#
# A z-score of -1 means the data point is one standard deviation below the mean.
#
# Use of Z-Statistic in Hypothesis Testing
# In hypothesis testing, the z-statistic is used to determine whether to reject the null hypothesis. Here’s a step-by-step outline of how it’s applied:
#
# **1. State the Hypotheses:**
#
# **Null Hypothesis (H0):** Assumes no effect or no difference. For example, 𝜇 = 𝜇0
#  (the population mean equals a specified value).
#
# **Alternative Hypothesis (H1):** Assumes an effect or a difference exists. For example,
# 𝜇≠𝜇0.
#
# **2. Calculate the Z-Score:**
#
# Use the sample data to calculate the z-score, which measures how far the sample mean is from the population mean, in terms of standard deviations.
#
# **3. Determine the Significance Level (𝛼):**
#
# Common significance levels are 0.05, 0.01, or 0.10.
#
# **4. Find the Critical Value(s) from the Z-Table:**
#
# For a two-tailed test with 𝛼=0.05, the critical values are approximately ±1.96.
#
# For a one-tailed test with 𝛼=0.05, the critical value is approximately ±1.645.
#
# **5. Compare the Z-Score to the Critical Value:**
#
# If the calculated z-score falls beyond the critical value(s), reject the null hypothesis.
#
# If the z-score falls within the critical range, fail to reject the null hypothesis.
#
# **6. Conclusion:**
#
# Based on the comparison, make a conclusion about the hypothesis.

# %% [markdown]
# **Q2 What is a p-value, and how is it used in hypothesis testing? What does it mean if the p-value is very small (e.g., 0.01)?**

# %% [markdown]
# **P-Value: Definition and Role in Hypothesis Testing**
#
# A **p-value** is a measure of the probability that an observed difference could have occurred just by random chance. In the context of hypothesis testing, it helps determine the strength of the evidence against the null hypothesis (H0).
#
# **Interpreting the P-Value:**
#
# **High P-Value:** A high p-value (typically > 0.05) indicates weak evidence against the null hypothesis, so you fail to reject it. This means that the observed data is consistent with the null hypothesis.
#
# **Low P-Value:** A low p-value (typically ≤ 0.05) indicates strong evidence against the null hypothesis, so you reject it. This suggests that the observed data is unlikely to have occurred under the null hypothesis.
#
# **Steps in Hypothesis Testing Using P-Value:**
#
# **1. State the Hypotheses:**
#
# **Null Hypothesis (H0):** There is no effect or difference. For example, 𝜇=𝜇0.
#
# **Alternative Hypothesis (H1):** There is an effect or difference. For example, 𝜇≠𝜇0.
#
# **2. Determine the Significance Level (α):**
#
# Common significance levels are 0.05, 0.01, or 0.10. This is the threshold for deciding whether to reject the null hypothesis.
#
# **3. Collect Data and Calculate the Test Statistic:**
#
# Calculate the appropriate test statistic (e.g., z-score, t-score) based on the data.
#
# **4. Calculate the P-Value:**
#
# Use the test statistic to find the p-value from the relevant statistical distribution (e.g., standard normal distribution).
#
# **5. Compare P-Value to Significance Level:**
#
# If 𝑝≤𝛼, reject the null hypothesis.
#
# If 𝑝>𝛼, fail to reject the null hypothesis.
#
# **Example Interpretation:**
# **Very Small P-Value (e.g., 0.01):**
#
# A p-value of 0.01 means there is only a 1% chance that the observed data would occur if the null hypothesis were true.
#
# This provides strong evidence against the null hypothesis.
#
# If the significance level is 0.05, you would reject the null hypothesis because 0.01 < 0.05.
#
# **Practical Implications:**
# Statistical Significance: A very small p-value indicates that the observed effect is statistically significant, suggesting that the effect is unlikely to be due to random variation alone.
#
# Real-World Decisions: While a low p-value indicates statistical significance, it doesn’t imply practical significance. It’s important to consider the effect size and real-world relevance of the findings.

# %% [markdown]
# **Q3. Compare and contrast the binomial and Bernoulli distributions.**

# %% [markdown]
# **Binomial vs. Bernoulli Distributions**
#
# While the binomial and Bernoulli distributions are closely related, they serve different purposes in probability theory. Let's explore their similarities and differences.
#
# **Bernoulli Distribution**
#
# **Definition:**
#
# The Bernoulli distribution describes the outcome of a single binary experiment, such as a coin flip, where there are only two possible outcomes: success (1) and failure (0).
#
# **Key Characteristics:**
# Number of Trials (n): 1
#
# Probability of Success (p): Given
#
# Probability Mass Function (PMF):
#
# 𝑃(𝑋=1)=𝑝
#
# 𝑃(𝑋=0)=1−𝑝
#
# Mean (µ): 𝑝
#
# Variance (σ²): 𝑝(1−𝑝)
#
# Example:
# Flipping a single coin where the probability of getting heads (success) is 0.5.
#
# **Binomial Distribution**
#
# **Definition:**
#
# The binomial distribution extends the Bernoulli distribution to multiple independent binary experiments (trials), where each trial has the same probability of success.
#
# **Key Characteristics:**
#
# Number of Trials (n): Greater than 1
#
# Probability of Success (p): Given and constant for each trial
#
# Probability Mass Function (PMF):
#
# 𝑃(𝑋=𝑘)=(𝑛𝑘)𝑝𝑘(1−𝑝)𝑛−𝑘
#
# Where (𝑛𝑘) is the binomial coefficient, and 𝑘 is the number of successes
#
# Mean (µ): 𝑛×𝑝
#
# Variance (σ²): 𝑛×𝑝(1−𝑝)
#
# Example:
# Flipping a coin 10 times and counting the number of heads, where the probability of getting heads in each flip is 0.5.
#
# **Relationship Between the Two**
#
# Special Case: The Bernoulli distribution is a special case of the binomial distribution where the number of trials
# 𝑛 is 1.
#
# Aggregation: The binomial distribution can be viewed as the sum of 𝑛 independent Bernoulli trials with the same probability of success.

# %% [markdown]
# **Q4. Under what conditions is the binomial distribution used, and how does it relate to the Bernoulli distribution?**

# %% [markdown]
# **Conditions for Using Binomial Distribution**
#
# The binomial distribution is appropriate under the following conditions:
#
# **1. Fixed Number of Trials (n):**
#
# There must be a specific number of trials or experiments.
#
# Example: Conducting 10 coin flips.
#
# **2. Binary Outcomes:**
#
# Each trial results in exactly one of two possible outcomes: success or failure.
#
# Example: Each coin flip results in either heads (success) or tails (failure).
#
# **3. Independence:**
#
# The outcome of one trial does not affect the outcome of another.
#
# Example: Each coin flip is independent of the others.
#
# **4. Constant Probability of Success (p):**
#
# The probability of success remains the same in each trial.
#
# Example: The probability of getting heads in each flip of a fair coin is 0.5.
#
# **Relationship to the Bernoulli Distribution**
#
# The binomial distribution can be seen as an extension of the Bernoulli distribution:
#
# **Bernoulli Distribution:**
#
# Describes the outcome of a single trial with two possible outcomes (success or failure).
#
# Parameters: Probability of success (p).
#
# Example: A single coin flip where the probability of getting heads is 0.5.
#
# **Binomial Distribution:**
#
# Describes the number of successes in a fixed number of independent Bernoulli trials.
#
# Parameters: Number of trials (n) and probability of success (p).
#
# Example: Counting the number of heads in 10 coin flips.

# %% [markdown]
# **Q5. What are the key properties of the Poisson distribution, and when is it appropriate to use this distribution?**

# %% [markdown]
# **Key Properties of the Poisson Distribution**
#
# The Poisson distribution is a discrete probability distribution that expresses the probability of a given number of events occurring within a fixed interval of time or space. It is particularly useful for modeling rare events.
#
# **1. Probability Mass Function (PMF):**
#
# The probability of observing 𝑘 events in an interval is given by: 𝑃(𝑋=𝑘)=𝜆𝑘𝑒−𝜆/𝑘!
# Where:
#
# 𝜆(lambda) is the average number of events in the interval.
#
# 𝑘 is the number of events.
#
# 𝑒 is Euler's number (approximately 2.71828).
#
# **2. Mean and Variance:**
#
# The mean of the Poisson distribution is 𝜆.
#
# The variance of the Poisson distribution is also 𝜆.
#
# **3. Memoryless Property:**
#
# The Poisson distribution exhibits the memoryless property, meaning that the probability of an event occurring in the next interval is independent of the events in previous intervals.
#
# **4. Shape:**
#
# The distribution is skewed to the right, especially when 𝜆 is small.
#
# As 𝜆 increases, the distribution approaches a normal distribution due to the Central Limit Theorem.
#
# **When to Use the Poisson Distribution**
#
# The Poisson distribution is appropriate under the following conditions:
#
# **1. Counting Events:**
#
# The distribution is used to count the number of events that occur in a fixed interval of time or space.
#
# **2. Independent Events:**
#
# The events must occur independently of one another. The occurrence of one event does not affect the probability of another event occurring.
#
# **3. Constant Rate:**
#
# The average rate (mean number of events,𝜆) at which events occur is constant throughout the interval.
#
# **4. Discrete Events:**
#
# The events are discrete and countable.
#
# **Practical Applications:**
#
# **1. Traffic Flow:**
#
# Modeling the number of cars passing through a toll booth in an hour.
#
# **2. Call Centers:**
#
# Counting the number of calls received by a call center in a day.
#
# **3. Biology:**
#
# Counting the number of mutations in a given stretch of DNA over a fixed length.
#
# **4. Finance:**
#
# Modeling the number of defaults in a portfolio of loans over a specified period.

# %% [markdown]
# **Q6. Define the terms "probability distribution" and "probability density function" (PDF). How does a PDF differ from a probability mass function (PMF)**

# %% [markdown]
# **Probability Distribution**
#
# A probability distribution describes how the values of a random variable are distributed. It provides the probabilities of occurrence of different possible outcomes in an experiment. Probability distributions can be discrete or continuous.
#
# Probability Density Function (PDF)
# A Probability Density Function (PDF) is used for continuous random variables. It represents the relative likelihood of a continuous random variable to take on a particular value. The PDF gives the probability that the random variable falls within a particular range of values, as opposed to taking on any one value.
#
# **Characteristics:**
#
# The value of the PDF at a given point represents the density of the probability at that point, not the actual probability.
#
# The area under the PDF curve over an interval represents the probability of the variable falling within that interval.
#
# The total area under the PDF curve over the entire range of possible values is equal to 1.
#
# **Probability Mass Function (PMF)**
#
# A Probability Mass Function (PMF) is used for discrete random variables. It gives the probability that a discrete random variable is exactly equal to some value.
#
# **Characteristics:**
#
# The PMF assigns probabilities to each possible value of the discrete random variable.
#
# The sum of all probabilities in the PMF is equal to 1.
#
# **Examples**
#
# **PDF Example:**
#
# Consider the height of individuals. The height can be any value within a range (e.g., 150 cm to 200 cm), and the PDF shows the density of probabilities for different height values.
#
# **PMF Example:**
#
# Consider the number of heads obtained when flipping a coin 10 times. The possible values are discrete (0 to 10), and the PMF gives the probability of each outcome (e.g., getting exactly 5 heads).

# %% [markdown]
# **Q.7 Explain the Central Limit Theorem (CLT) with example.**

# %% [markdown]
# **Central Limit Theorem (CLT)**
#
# The Central Limit Theorem (CLT) is one of the most important concepts in statistics. It states that the sampling distribution of the sample mean (or sum) of a sufficiently large number of independent, identically distributed (i.i.d.) random variables, regardless of the shape of the original population distribution, will approximate a normal distribution. This convergence to the normal distribution occurs even if the original variable is not normally distributed.
#
# **Key Points of the CLT:**
#
# **Sample Size:** The theorem applies to sufficiently large sample sizes. Typically, a sample size greater than 30 is considered adequate, though the required size can vary depending on the original distribution.
#
# **Independence:** The samples must be independent of each other.
#
# **Identically Distributed:** The samples must come from the same distribution with a fixed mean and variance.
#
# **Mathematical Expression:**
#
# If 𝑋1,𝑋2,…,𝑋𝑛are i.i.d. random variables with mean 𝜇 and variance 𝜎2, then the sample mean 𝑋 will be approximately normally distributed with mean 𝜇 and variance 𝜎 2 𝑛 as 𝑛 becomes large.
#
# **Example:**
#
# Let's say we want to understand the average height of adult women in a city. The population distribution of heights is not known to be normal, but we can use the CLT to approximate the distribution of the sample mean.
#
# **1. Population Mean and Variance:** Assume the mean height (𝜇) is 165 cm, and the standard deviation (𝜎) is 10 cm.
#
# **2. Sample Size:** We take a random sample of 50 women (n = 50).
#
# According to the CLT, the distribution of the sample mean height will be approximately normal, even if the original height distribution is not normal.
#
# **Calculation:**
#
# Mean of the Sampling Distribution: The mean (𝜇𝑋ˉ) of the sampling distribution will be the same as the population mean, which is 165 cm.
#
# **Standard Error:** The standard deviation of the sampling distribution (standard error) is given by 𝜎/√𝑛.
#
# Standard error = 10/√50 ≈ 1.41
#
# Therefore, the sampling distribution of the sample mean height of 50 women will be approximately normally distributed with:
#
# Mean (𝜇𝑋) = 165 cm
#
# Standard Error (𝜎𝑋) = 1.41 cm
#
# **Visualization:**
#
# If we were to take multiple samples of 50 women and calculate the sample mean height for each sample, we would see that the distribution of these sample means forms a normal distribution centered around 165 cm with a standard error of 1.41 cm.
#
# **Practical Implications:**
#
# **Inference:** The CLT allows us to make inferences about population parameters using the normal distribution, even when the population distribution is unknown.
#
# **Confidence Intervals:** It helps in constructing confidence intervals for population means.
#
# **Hypothesis Testing:** Facilitates hypothesis testing for population means using z-scores and t-scores.

# %% [markdown]
# **Q8. Compare z-scores and t-scores. When should you use a z-score, and when should a t-score be a pplied instead?**

# %% [markdown]
# **Z-Scores vs. T-Scores**
#
# Z-scores and t-scores are both statistical measures used to determine how far a sample mean is from the population mean in terms of standard deviations. However, they are used under different conditions and have distinct formulas.
#
# **Z-Scores**
#
# **Definition:**
#
# A z-score measures the number of standard deviations a data point is from the population mean. It is used when the population standard deviation (𝜎) is known.
#
# **Formula:**
#
# 𝑧= 𝑥−𝜇/𝜎/√𝑛
#
# Where:
#
# 𝑥 = sample mean
#
# 𝜇 = population mean
#
# 𝜎 = population standard deviation
#
# 𝑛 = sample size
#
# **When to Use:**
#
# **Population Standard Deviation Known:** When the population standard deviation is known and the sample size is large (𝑛≥30).
#
# **Normal Distribution:** When the data is normally distributed or the sample size is sufficiently large for the Central Limit Theorem to apply.
#
# **T-Scores**
#
# **Definition:**
#
# A t-score measures the number of standard deviations a sample mean is from the population mean, accounting for the sample size. It is used when the population standard deviation (𝜎) is unknown and must be estimated from the sample.
#
# **Formula:𝑡=𝑥−𝜇/𝑠/√𝑛
#
# Where:
#
# 𝑥 = sample mean
#
# 𝜇 = population mean
#
# 𝑠 = sample standard deviation
#
# 𝑛 = sample size
#
# **When to Use:**
#
# **Population Standard Deviation Unknown:** When the population standard deviation is unknown and you use the sample standard deviation instead.
#
# **Small Sample Size:** When the sample size is small (𝑛<30).
#
# **Student's T-Distribution:** When the data follows or can be approximated by the Student's t-distribution, which accounts for the additional variability introduced by estimating the population standard deviation from a small sample.

# %% [markdown]
# **Q9 Given a sample mean of 105, a population mean of 100, a standard deviation of 15, and a sample size of 25, calculate the z-score and p-value. Based on a significance level of 0.05, do you reject or fail to reject the null hypothesis?**
#
# **Task: Write Python code to calculate the z-score and p-value for the given data.**
#
# **Objective: Apply the formula for the z-score and interpret the p-value for hypothesis testing.**

# %% [markdown]
# Given Data:
# Sample mean (𝑥) = 105
#
# Population mean (𝜇) = 100
#
# Standard deviation (𝜎) = 15
#
# Sample size (𝑛) = 25
#
# Significance level (𝛼) = 0.05
#
# **Calculate the P-value**
#
# The p-value can be found using the cumulative distribution function (CDF) of the standard normal distribution. Since it's a two-tailed test, we need to consider both tails of the distribution.
#
# Here is the Python code to calculate the z-score and p-value:

# %%
import scipy.stats as stats
import math

# Given data
sample_mean = 105
population_mean = 100
std_dev = 15
sample_size = 25
significance_level = 0.05

# Calculate the z-score
z_score = (sample_mean - population_mean) / (std_dev / math.sqrt(sample_size))

# Calculate the p-value
p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

# Determine whether to reject or fail to reject the null hypothesis
reject_null = p_value < significance_level

# Output the results
print(f"Z-score: {z_score}")
print(f"P-value: {p_value}")
print(f"Reject null hypothesis: {reject_null}")
# Out:
# Z-score: 1.6666666666666667
# P-value: 0.09558070454562939
# Reject null hypothesis: False

# %% [markdown]
# **Interpretation:**
#
# Z-score: A z-score of approximately 1.67 means that the sample mean is 1.67 standard deviations above the population mean.
#
# P-value: This value tells us the probability of observing a sample mean as extreme as 105, assuming the null hypothesis is true.
#
# **Decision:**
# If the p-value is less than the significance level (0.05), we reject the null hypothesis.
#
# If the p-value is greater than the significance level, we fail to reject the null hypothesis.

# %% [markdown]
# **Q.10 Simulate a binomial distribution with 10 trials and a probability of success of 0.6 using Python. Generate 1,000 samples and plot the distribution. What is the expected mean and variance?**
#
# **Task: Use Python to generate the data, plot the distribution, and calculate the mean and variance.**
#
# **Objective: Understand the properties of a binomial distribution and verify them through simulation.**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
n_trials = 10
p_success = 0.6
n_samples = 1000

# Simulate binomial distribution
samples = np.random.binomial(n=n_trials, p=p_success, size=n_samples)

# Calculate the expected mean and variance
expected_mean = n_trials * p_success
expected_variance = n_trials * p_success * (1 - p_success)

# Plot the distribution
plt.hist(samples, bins=np.arange(0, n_trials+2) - 0.5, edgecolor='black', density=True)
plt.title('Binomial Distribution (n=10, p=0.6) with 1000 samples')
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.show()

# Print expected mean and variance
print(f"Expected Mean: {expected_mean}")
print(f"Expected Variance: {expected_variance}")
# Out:
# Expected Mean: 6.0
# Expected Variance: 2.4000000000000004

# %% [markdown]
# **Explanation:**
#
# Simulating Binomial Distribution: The np.random.binomial function generates 1,000 samples of a binomial distribution with 10 trials and a probability of success of 0.6.
#
# Plotting the Distribution: The plt.hist function plots the histogram of the samples to visualize the distribution.
#
# Expected Mean and Variance:
#
# Expected Mean: For a binomial distribution, the expected mean (µ) is given by
# 𝜇 = 𝑛×𝑝.
#
# Expected Variance: The variance (σ²) is given by 𝜎2 =𝑛×𝑝×(1−𝑝).
#
# **Results:**
#
# **Expected Mean:** 10 × 0.6 = 6
#
# **Expected Variance:** 10 × 0.6 × ( 1 − 0.6 ) = 2.4
#
# This code will generate the histogram showing the probability distribution of the number of successes in 10 trials, with 1,000 samples, and will print the expected mean and variance of the distribution.
#
# Run this code in your Python environment to visualize the distribution and verify the properties of the binomial distribution. If you have any questions or need further assistance, feel free to ask!
